# %% [markdown]
# ## practice question

# %%
x = 5
y = x
x = 9

print(x)
print(y)
# Out:
# 9
# 5

# %%
a = b = 100

print(id(a) == id(b))
# Out:
# True

# %%
name1 = "Python"
name2 = name1
name1 = "Java"

print(name1)
print(name2)
# Out:
# Java
# Python

# %%
numbers = values = []

numbers.append(1)

print(numbers)
print(values)
# Out:
# [1]
# [1]

# %% [markdown]
# 2. Mutable VS Immutable Objects

# %% [markdown]
# --Immutable Objects -
#
# int ,float ,str ,complex ,bool ,tuple , bytes ,frozenset ,None

# %%
x = 10

print(id(x))

x = 20

print(id(x))
# Out:
# 4383711424
# 4383711744

# %%
numbers = [10,20]

print(id(numbers))

numbers.append(30)

print(id(numbers))
# Out:
# 5114279552
# 5114279552

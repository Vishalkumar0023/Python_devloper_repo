# %% [markdown]
# ## practice question

# %%
x = 5
y = x
x = 9

print(x)
print(y)
# Out:
# 9
# 5

# %%
a = b = 100

print(id(a) == id(b))
# Out:
# True

# %%
name1 = "Python"
name2 = name1
name1 = "Java"

print(name1)
print(name2)
# Out:
# Java
# Python

# %%
numbers = values = []

numbers.append(1)

print(numbers)
print(values)
# Out:
# [1]
# [1]

# %% [markdown]
# 2. Mutable VS Immutable Objects

# %% [markdown]
# --Immutable Objects -
#
# int ,float ,str ,complex ,bool ,tuple , bytes ,frozenset ,None

# %% [markdown]
# Mutable Types-

# %% [markdown]
# list
# dict
# set
# bytearray
# most class instances

# %%
x = 10

print(id(x))

x = 20

print(id(x))
# Out:
# 4383711424
# 4383711744

# %%
numbers = [10,20]

print(id(numbers))

numbers.append(30)

print(id(numbers))
# Out:
# 5114279552
# 5114279552

# %%
# string are immutable 


text = "Python"

text[0] = "J"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 text = "Python"
# ----> 3 text[0] = "J"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Python refuses to modify them.
#
#
# Correct approach

# %%
text = "Python"

text = "J" + text[1:]

print(text)
print("A completely new string object is created.")
# Out:
# Jython
# A completely new string object is created.

# %%
student = {"name":"Alex"}

print(id(student))

student["age"] = 20

print(id(student))
# Out:
# 5130884096
# {'name': 'Alex', 'age': 20}
# 5130884096

# %%
skills = {"Python"}

skills.add("SQL")
print(skills)
# Out:
# {'Python', 'SQL'}

# %%
numbers = (1,2,3)

numbers[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 numbers = (1,2,3)
# ----> 3 numbers[0] = 100
#       4 print("Tuples are immutable, so you cannot change their elements.")
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Tuples are immutable, so you cannot change their elements.

# %%
def add_user(users):
    users.append("Alice")

team = ["Bob", "Carol"]
add_user(team)

print(team)
# Out:
# ['Bob', 'Carol', 'Alice']

# %%
a = [1, 2]
b = a

a.append(3)

print(b)
# Out:
# [1, 2, 3]

# %%
name = "Python"

name += "3"

print(name)
# Out:
# Python3

# %%
t = (1, 2, 3)

t[1] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 t = (1, 2, 3)
# ----> 3 t[1] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Tuples can not modified ,Tuple is immutable

# %% [markdown]
# # Identity (is) vs Equality (==)

# %%
a = [1, 2, 3]
b = [1, 2, 3]
print(a == b)
print(a is b)
# Out:
# True
# False

# %%
a = [1, 2, 3]
b = a
print(a == b)
print(a is b)
# Out:
# True
# True

# %%
a = "Python"
b = "Python"
print(a == b)
print(a is b)
# Out:
# True
# True

# %%
a = 100
b = 100

print(a is b)
# Out:
# True

# %%
a = 1000
b = 1000

print(a is b)
# Out:
# False

# %% [markdown]
# Do not use "is" to compare numeric values.

# %%
result = None
if result is None:
    print("No result")
# Out:
# No result

# %% [markdown]
# The standard Python style is:
#
# is None

# %%
def find_user(user_id):
    # Search database
    # Return user if found
    # Return None if not found
    return None

# %%
user = find_user(101)
if user is None:
    print("User not found")
# Out:
# User not found

# %%
if user is not None:
    print("User found")

# %% [markdown]
# # Mistakes

# %%
x = 10

if x is 10:
    print("Equal")
# Out:
# Equal
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /var/folders/6j/dpgtdc3j5g7c5p_pfn2b2mtm0000gn/T/ipykernel_7520/38344755.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   if x is 10:

# %%
a = [1, 2, 3]
b = [1, 2, 3]
c = a

print(a == b)  # True
print(a is b)  # False

print(a == c)  # True
print(a is c)  # True
# Out:
# True
# False
# True
# True

# %% [markdown]
# a and c
#
# Same object
# Same value
#
#
# a and b
#
# Different objects
# Same value

# %% [markdown]
# == Can Be Customized

# %% [markdown]
# This is an advanced but important point.
#
# When you write:
#
# a == b
#
# Python generally invokes the object's equality behavior.
#
# For user-defined classes, you can define:

# %%
print("__eq__()")
# Out:
# __eq__()

# %% [markdown]
# Example:

# %%
class Student:
    def __init__(self, name):
        self.name = name

    def __eq__(self, other):
        return self.name == other.name

# %%
student1 = Student("Vishal")
student2 = Student("Vishal")

# %%
print(student1 == student2)
# Out:
# True

# %% [markdown]
# because their equality behavior says they are equal.

# %%
print(student1 is student2)
# Out:
# False

# %% [markdown]
# because they are separate objects.
#
# == is about logical equality.
#
# is is about physical/object identity.

# %% [markdown]
# user1 = get_user(101)
#
# user2 = get_user(101)
#
# These could represent the same database user:
#
# user1.id == user2.id
#
# but still be different Python objects:
#
# user1 is user2
#
# could be:
#
# False
#
# This is completely normal.

# %% [markdown]
# # Object Identity Experiment

# %%
a = [1, 2, 3]
b = [1, 2, 3]
c = a

print("a == b:", a == b)
print("a is b:", a is b)

print("a == c:", a == c)
print("a is c:", a is c)

print("ID of a:", id(a))
print("ID of b:", id(b))
print("ID of c:", id(c))
# Out:
# a == b: True
# a is b: False
# a == c: True
# a is c: True
# ID of a: 4392973696
# ID of b: 4392973824
# ID of c: 4392973696

# %% [markdown]
# # Module 5 — Shallow Copy, Deep Copy, and Object Copying

# %%
a = [
    [1, 2],
    [3, 4]
]

b = a.copy()

b[0].append(100)

print(a)
print(b)
# Out:
# [[1, 2, 100], [3, 4]]
# [[1, 2, 100], [3, 4]]

# %%
print(a[0] is b[0])
# Out:
# True

# %%
print(a is b)
# Out:
# False

# %% [markdown]
# This is the exact behavior of a shallow copy.

# %% [markdown]
# Deep Copy

# %%
import copy

# %%
b = copy.deepcopy(a)

# %%
import copy

a = [
    [1, 2],
    [3, 4]
]

b = copy.deepcopy(a)

b[0].append(100)

print(a)
print(b)
# Out:
# [[1, 2], [3, 4]]
# [[1, 2, 100], [3, 4]]

# %%
print(a is b)
# Out:
# False

# %%
print(a[0] is b[0])
# Out:
# False

# %% [markdown]
# The Three Models

# %%
# 1
b = a

# %%
# 2
b = a.copy()

# %%
# 3
b = copy.deepcopy(a)

# %% [markdown]
# Copying Dictionaries

# %%
user = {
    "name": "Vishal",
    "skills": ["Python", "SQL"]
}

# %%
user_copy = user.copy()

# %%
print(user["skills"] is user_copy["skills"])
# Out:
# True

# %%
user_copy["skills"].append("ML")

# %%
user["skills"]
# Out:
# ['Python', 'SQL', 'ML']

# %% [markdown]
# Imagine an API configuration:

# %%
default_config = {
    "database": {
        "host": "localhost",
        "port": 5432
    }
}

# %% [markdown]
# You want a configuration for a new environment.
#
# A developer writes:

# %%
production_config = default_config.copy()

# %%
production_config["database"]["host"] = "prod-db.example.com"

# %% [markdown]
# Now the original configuration has also changed.

# %% [markdown]
# Because:
#
# default_config["database"]
#
# and
#
# production_config["database"]
#
# refer to the same nested dictionary.
#
# This can cause extremely difficult bugs in real applications.

# %%
import copy

production_config = copy.deepcopy(default_config)

# %%
settings = {
    "theme": "dark",
    "language": "en"
}

# %%
user_settings = settings.copy()

user_settings["theme"] = "light"

# %%
print(settings)
print(user_settings)
# Out:
# {'theme': 'dark', 'language': 'en'}
# {'theme': 'light', 'language': 'en'}

# %% [markdown]
# List Slicing

# %%
a = [[1, 2], [3, 4]]

b = a[:]

# %%
a is b
# Out:
# False

# %%
a[0] is b[0]
# Out:
# True

# %% [markdown]
# Tuple Trap

# %%
data = ([1, 2], [3, 4])

# %%
data[0] = [100]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 data[0] = [100]
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# This fails.
#
# But the list inside the tuple is mutable:

# %%
data[0].append(100)

# %%
data
# Out:
# ([1, 2, 100], [3, 4])

# %% [markdown]
# This is a crucial advanced concept:
#
# An immutable container does not guarantee that everything inside it is immutable.
#
# The tuple is immutable.
#
# The objects referenced by the tuple may not be.

# %% [markdown]
# Immutable Does Not Mean "Completely Frozen"

# %%
def clean_data(data):
    cleaned = data.copy()
    cleaned.drop_duplicates(inplace=True)
    return cleaned

# %% [markdown]
# The caller can then reason about whether the original data is preserved.

# %% [markdown]
# # Function Arguments and Python's Object Reference Model

# %%
def change(x):
    x = 100

a = 10

change(a)

print(a)
# Out:
# 10

# %% [markdown]
# x = something
#
# you are changing what the local name x refers to.
#
# You are not automatically changing the caller's variable.
#
# This is why:

# %%
def change(data):
    data.append(100)

numbers = [1, 2, 3]

change(numbers)

print(numbers)
# Out:
# [1, 2, 3, 100]

# %%
def change_number(x):
    x = 100

def change_list(data):
    data.append(100)

a = 10
numbers = [1, 2, 3]

change_number(a)
change_list(numbers)

print(a)
print(numbers)
# Out:
# 10
# [1, 2, 3, 100]

# %% [markdown]
# Python Is Not "Pass by Reference"

# %%
def change(data):
    data = ["new"]

numbers = [1, 2, 3]

change(numbers)

print(numbers)
# Out:
# [1, 2, 3]

# %% [markdown]
# If Python were traditional pass-by-reference in the sense used in some languages, rebinding data might have changed numbers.
#
# It doesn't.
#
# Therefore, saying:
#
# Python is pass-by-reference
#
# is misleading.

# %%
def process(data):
    data = [100, 200]

numbers = [1, 2, 3]

process(numbers)

print(numbers)
# Out:
# [1, 2, 3]

# %%
def process(data):
    data.append(100)

numbers = [1, 2, 3]

process(numbers)

print(numbers)
# Out:
# [1, 2, 3, 100]

# %% [markdown]
# Python passes references to objects, and the function receives its own local parameter name bound to that object.

# %%
def process(data):
    data.append(100)
    data = [500]

numbers = [1, 2, 3]

process(numbers)

print(numbers)
# Out:
# [1, 2, 3, 100]

# %%
def update(user):
    user["age"] = 21

person = {
    "name": "Vishal"
}

update(person)

print(person)
# Out:
# {'name': 'Vishal', 'age': 21}

# %% [markdown]
# Dictionaries are mutable.
#
# The function mutated the shared object.

# %%
def change(text):
    text += " World"

message = "Hello"

change(message)

print(message)
# Out:
# Hello

# %% [markdown]
# Strings are immutable.

# %%
def modify(data):
    data += [100]

numbers = [1, 2, 3]

modify(numbers)

print(numbers)
# Out:
# [1, 2, 3, 100]

# %%
def modify(data):
    data = data + [100]

numbers = [1, 2, 3]

modify(numbers)

print(numbers)
# Out:
# [1, 2, 3]

# %%
def add_item(item, items=[]):
    items.append(item)
    return items

# %%
print(add_item(1))
print(add_item(2))
print(add_item(3))
# Out:
# [1]
# [1, 2]
# [1, 2, 3]

# %%
def add_item(item, items=None):
    if items is None:
        items = []

    items.append(item)

    return items

# %%
print(add_item(1))
print(add_item(2))
print(add_item(3))
# Out:
# [1]
# [2]
# [3]

# %% [markdown]
# Production Example

# %%
def build_pipeline(steps=[]):
    steps.append("load_data")
    return steps

# %% [markdown]
# Potential behavior:
#
# First request
# ["load_data"]
#
# Second request
# ["load_data", "load_data"]
#
# Third request
# ["load_data", "load_data", "load_data"]

# %% [markdown]
# Correct:

# %%
def build_pipeline(steps=None):
    if steps is None:
        steps = []

    steps.append("load_data")
    return steps

# %%
def remove_invalid(records):
    records[:] = [
        record
        for record in records
        if record["valid"]
    ]

# %% [markdown]
# This modifies the original list in place.
#
# That may be intentional.
#
# But if the function is supposed to return a new list without modifying the caller's data, use:

# %%
def remove_invalid(records):
    return [
        record
        for record in records
        if record["valid"]
    ]

# %% [markdown]
# Mutation vs Non-Mutation API Design

# %% [markdown]
# Option A — Mutate input

# %%
def sort_data(data):
    data.sort()

# %% [markdown]
# The caller's object changes.

# %% [markdown]
# Option B — Return a new object

# %%
def sort_data(data):
    return sorted(data)

# %% [markdown]
# The caller's original object remains unchanged.
#
# Neither is universally correct.
#
# The important thing is that the behavior is:
#
# intentional
# documented
# predictable

# %%
numbers = [3, 1, 2]

result = numbers.sort()

print(numbers)
print(result)
# Out:
# [1, 2, 3]
# None

# %%
numbers = [3, 1, 2]

result = sorted(numbers)

print(numbers)
print(result)
# Out:
# [3, 1, 2]
# [1, 2, 3]

# %% [markdown]
# Mistake 1
#
# Saying:
#
# Python is pass-by-reference.
#
# Too simplistic and misleading.
#
# Better:
#
# Python passes object references by value.

# %% [markdown]
# Mistake 2
#
# Thinking mutation and rebinding are the same.
#
# They are not.
#
# x = new_object
#
# rebinds.
#
# x.append(value)
#
# mutates.

# %% [markdown]
# Mistake 3
#
# Thinking immutable arguments can never be affected.
#
# The function can still rebind its local parameter, but that does not modify the caller's variable.

# %% [markdown]
# Mistake 4
#
# Using mutable default arguments.
#
# Avoid:
#
# def func(data=[]):
#
# unless you intentionally want persistent shared state.

# %% [markdown]
# Mistake 5
#
# Writing functions that silently mutate input data.
#
# This can create difficult-to-debug side effects.

# %%
def modify(a, b, c):
    a = 100
    b.append(100)
    c["x"] = 100

x = 10
y = []
z = {}

modify(x, y, z)

print(x)
print(y)
print(z)
# Out:
# 10
# [100]
# {'x': 100}

# %%
def change(x):
    x = 20

a = 10
change(a)

print(a)
# Out:
# 10

# %%
def change(x):
    x.append(20)

a = [10]
change(a)

print(a)
# Out:
# [10, 20]

# %%
def change(x):
    x = [20]

a = [10]
change(a)

print(a)
# Out:
# [10]

# %%
# revision
def change(x):
    x += [20]

a = [10]
change(a)

print(a)
# Out:
# [10, 20]

# %%
def change(x):
    x = x + [20]

a = [10]
change(a)

print(a)
# Out:
# [10]

# %% [markdown]
# # Python Memory Management

# %% [markdown]
# Chapter 1 — What Does "Memory Management" Mean?
#
# Before learning reference counting or garbage collection, understand the actual problem.
#
# Every program needs memory to store things like:

# %%
name = "Vishal"
age = 21
numbers = [1, 2, 3]

# %% [markdown]
# Python creates objects to represent these values.
#
# Conceptually:
#
# name ─────► "Vishal"
#
# age ──────► 21
#
# numbers ──► [1, 2, 3]
#
# The Python runtime has to answer two basic questions:
#
# Where should objects be stored?
# When can their memory be reclaimed?
#
# Memory management is about handling the lifecycle of these objects.

# %% [markdown]
# Chapter 2 — Variables Do Not Own Memory in the Way Beginners Think

# %% [markdown]
# Consider:
#
# x = 10
#
# A beginner might imagine:
#
# x
#
# ┌─────────┐
# │   10    │
# └─────────┘
#
#
# This is a useful beginner abstraction, but it is not the best mental model for Python.
#
# A better model is:
#
# x ─────────► Integer Object: 10
#
# Now:
#
# y = x
#
# becomes:
#
#
# x ───────┐
#          ▼
#         10
#          ▲
#          │
# y ───────┘
#
#
# There is one object and two names.
#
# This is why understanding references is necessary before understanding memory management.

# %% [markdown]
# Chapter 3 — Object Lifetime
#
# Every Python object has a lifetime.
#
# Conceptually:
#
# Object Created
#
#       ↓
#
# Object Used
#
#       ↓
#
# Object Referenced
#
#       ↓
#
# References Removed
#
#       ↓
#
# Object Becomes Unreachable
#
#       ↓
#
# Memory Can Be Reclaimed

# %%
x = [1, 2, 3]

# %% [markdown]
# An object is created.
#
# Then:

# %%
y = x

# %% [markdown]
# Now two names refer to it.
#
# Then:

# %%
del x

# %% [markdown]
# The list still exists because:
#
# y ─────► [1, 2, 3]
#
# Now:

# %%
del y

# %% [markdown]
# If no other references exist, the object becomes unreachable.
#
# Conceptually:
#
# No references
#
#      ↓
#
# Object is unreachable
#
#      ↓
#
# Python can reclaim it
#
# This leads us to one of the most important concepts in CPython:
#
# Reference Counting

# %% [markdown]
# Chapter 4 — Reference Counting

# %% [markdown]
# Conceptually:
#
# Reference count → 0
#
#         ↓
#
# Object becomes unreachable
#
#         ↓
#
# CPython can deallocate it
#
# This is the basic idea behind reference counting.

# %% [markdown]
# Chapter 5 — del Does Not Mean "Delete the Object"

# %% [markdown]
# del x removes the name binding.
#
# It does not necessarily destroy the object.
#
# This distinction is critical:
#
# del variable
#
#        ↓
#
# Remove a reference/name
#
#        ↓
#
# Not necessarily destroy object

# %% [markdown]
# Chapter 6 — del and Object Lifetime

# %%
x = [1, 2, 3]
del x

# %% [markdown]
# if x was the only reference to the object, the object may become unreachable.
#
# But:

# %%
x = [1, 2, 3]
y = x

del x

# %% [markdown]
# The object remains reachable through y.
#
# So:
#
# del x
#
# means:
#
# Remove the name x from its namespace.
#
# It does not mean:
#
# Forcefully destroy the object

# %% [markdown]
# Chapter 7 — Measuring Reference Counts
#
# Python provides:

# %%
import sys

# %% [markdown]
# You can inspect reference counts with:

# %%
sys.getrefcount()

# %% [markdown]
# Example:

# %%
import sys

x = []

print(sys.getrefcount(x))
# Out:
# 2

# %% [markdown]
# But don't immediately conclude:
#
# "The object has exactly two references."
#
# There is an important reason.
#
# When you call:

# %%
sys.getrefcount(x)

# %% [markdown]
# the function itself temporarily receives a reference to the object.
#
# So the reported number is typically one higher than the count you might expect from your own references.
#
# Example:

# %%
x = []
y = x

# %% [markdown]
# You may see a count reflecting:
#
# x
# y
# temporary function argument
#
# This makes sys.getrefcount() useful for experimentation, but not something you should casually rely on for application logic.

# %% [markdown]
# Chapter 8 — Reference Counting Is Not Enough

# %%
a = []
b = []

a.append(b)
b.append(a)

# %% [markdown]
# The objects reference each other.
#
# Now:

# %%
del a
del b

# %% [markdown]
# From the program's namespace, the names are gone.
#
# But conceptually:
#
# The objects still reference each other.
#
# Their reference counts may not reach zero.
#
# This creates a reference cycle.
#
# Reference counting alone cannot solve this.
#
# This is why Python also has:
#
# Garbage Collection

# %% [markdown]
# Chapter 9 — Garbage Collection

# %% [markdown]
# Python's garbage collector can detect certain groups of objects that are no longer reachable from the program but still reference one another.

# %% [markdown]
# Python provides the gc module:

# %%
import gc

# %% [markdown]
# You can inspect whether automatic garbage collection is enabled:

# %%
print(gc.isenabled())
# Out:
# True

# %% [markdown]
# You can manually trigger collection:

# %%
gc.collect()
# Out:
# 563

# %% [markdown]
# But in normal application code, you generally should not manually call gc.collect() everywhere.
#
# The garbage collector is designed to operate automatically.

# %% [markdown]
# Chapter 10 — Reference Counting vs Garbage Collection

# %% [markdown]
# Reference Counting. ---- Tracks references to objects
#
# Cyclic Garbage Collector --- Handles unreachable reference cycles

# %% [markdown]
# Chapter 11 — Reference Cycles

# %% [markdown]
# Let's create a simple cycle:

# %%
a = []
a.append(a)

# %% [markdown]
# The list contains a reference to itself.
#
# Now:

# %%
del a

# %% [markdown]
# The name a disappears.
#
# But the object has a self-reference.
#
# This is a cycle.
#
# The cyclic garbage collector can detect such unreachable cyclic structures.
#
# This is why Python's memory management is more complicated than:
#
# "Reference count reaches zero, object disappears."
#
# That statement is incomplete.

# %% [markdown]
# Chapter 12 — Generational Garbage Collection

# %% [markdown]
# Python's cyclic garbage collector uses a generational approach.
#
# The underlying idea is based on an observation:
#
# Objects that survive for a long time are often more likely to continue surviving.
#
# So objects are conceptually organized by age/generation.
#
# The garbage collector focuses more frequently on newer objects and less frequently on older ones.

# %%
import tracemalloc

tracemalloc.start()

# Code that allocates memory

snapshot = tracemalloc.take_snapshot()

for statistic in snapshot.statistics("lineno")[:10]:
    print(statistic)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3517: size=296 B, count=1, average=296 B
# /opt/anaconda3/lib/python3.13/codeop.py:118: size=294 B, count=2, average=147 B
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3577: size=160 B, count=1, average=160 B
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3507: size=64 B, count=2, average=32 B
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3566: size=64 B, count=1, average=64 B
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/compilerop.py:192: size=32 B, count=1, average=32 B

# %% [markdown]
# # Namespaces and Scope

# %%
x = 10

def test():
    print(x)
    x = 20

test()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[22], line 7
#       4     print(x)
#       5     x = 20
# ----> 7 test()
#
# Cell In[22], line 4, in test()
#       3 def test():
# ----> 4     print(x)
#       5     x = 20
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %% [markdown]
# Because Python determines that x is local to test()

# %%
"""
Module 2: Dynamic Typing and Strong Typing

Topics:
- Dynamic typing
- Strong typing
- Name rebinding
- Runtime type checking
- Explicit type conversion
"""


def demonstrate_dynamic_typing():
    print("=== Dynamic Typing ===")

    x = 10
    print(f"x = {x}, type = {type(x).__name__}")

    x = "Python"
    print(f"x = {x}, type = {type(x).__name__}")

    x = [1, 2, 3]
    print(f"x = {x}, type = {type(x).__name__}")


def demonstrate_strong_typing():
    print("\n=== Strong Typing ===")

    # Compatible numeric types
    result = 10 + 2.5
    print(f"10 + 2.5 = {result}")

    # Incompatible types
    try:
        result = 10 + "20"
        print(result)
    except TypeError as error:
        print(f"TypeError: {error}")

    # Explicit conversion
    result = 10 + int("20")
    print(f"10 + int('20') = {result}")


def demonstrate_rebinding():
    print("\n=== Rebinding ===")

    x = 10
    print(f"Initial: x = {x}, type = {type(x).__name__}")

    x = "10"
    print(f"After rebinding: x = {x}, type = {type(x).__name__}")

    x = [10]
    print(f"After rebinding again: x = {x}, type = {type(x).__name__}")


def main():
    demonstrate_dynamic_typing()
    demonstrate_strong_typing()
    demonstrate_rebinding()


if __name__ == "__main__":
    main()
# Out:
# === Dynamic Typing ===
# x = 10, type = int
# x = Python, type = str
# x = [1, 2, 3], type = list
#
# === Strong Typing ===
# 10 + 2.5 = 12.5
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
# 10 + int('20') = 30
#
# === Rebinding ===
# Initial: x = 10, type = int
# After rebinding: x = 10, type = str
# After rebinding again: x = [10], type = list

# %%
value = [0]
if value :
    print("Value is truthy")    
else:
    print("Value is falsy")
# Out:
# Value is truthy

# %%
value = 0

if value:
    print("A")
elif value is None:
    print("B")
else:
    print("C")
# Out:
# C

# %%
value = None

if value:
    print("A")
elif value is None:
    print("B")
else:
    print("C")
# Out:
# B

# %%
value = []

if value:
    print("A")
elif value is None:
    print("B")
else:
    print("C")
# Out:
# C

# %%
value = [0]

if value:
    print("A")
elif value is None:
    print("B")
else:
    print("C")
# Out:
# A

# %%
text = "Hello"
data = text.encode("utf-8")
original = data.decode("utf-8")

# %%
print(f"Original: {text}, Encoded: {data}, Decoded: {original}")
# Out:
# Original: Hello, Encoded: b'Hello', Decoded: Hello

# %%
type(data)
# Out:
# bytes

# %%
# hello 
print(data[0])
# Out:
# 72

# %%
text = "नमस्ते"

data = text.encode("utf-8")

# %%
print(f"Original: {text}, Encoded: {data}, Decoded: {original}")
# Out:
# Original: नमस्ते, Encoded: b'\xe0\xa4\xa8\xe0\xa4\xae\xe0\xa4\xb8\xe0\xa5\x8d\xe0\xa4\xa4\xe0\xa5\x87', Decoded: Hello

# %%
print(data[0])
# Out:
# 224

# %% [markdown]
# bytearray is similar to bytes, but mutable.

# %%
data = bytearray(b"ABC")

# %%
data[0] = 90

# %%
print(data)
# Out:
# bytearray(b'ZBC')

# %% [markdown]
# Practical Example
#
# Suppose an API sends this:

# %%
response_data = b'{"name": "Vishal"}'

# %%
text = response_data.decode("utf-8")

# %%
text
# Out:
# '{"name": "Vishal"}'

# %%
import json

data = json.loads(text)

# %%
data
# Out:
# {'name': 'Vishal'}

# %%
data = b"Hello"
text = data.decode("utf-8")

print(type(data))
print(type(text))

# %%
text = "न"
data = text.encode("utf-8")

print(len(text))
print(len(data))
# Out:
# 1
# 3

# %%
text = "नमस्ते"

data = text.encode("utf-8")

print(data[0])
print(len(text))
print(len(data))
# Out:
# 224
# 6
# 18

# %%
numbers = [10, 20, 30, 40, 50]

print(numbers[1])
print(numbers[-2])
print(numbers[1:4])
print(numbers[::-1])
# Out:
# 20
# 40
# [20, 30, 40]
# [50, 40, 30, 20, 10]

# %%
numbers = [1, 2, 3, 4, 5]

first, *middle, last = numbers

print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4]
# 5

# %%
data = ([1, 2], 10)

data[0].append(3)

print(data)
# Out:
# ([1, 2, 3], 10)

# %%
x = None

print(bool(x))
print(x is None)
# Out:
# False
# True

# %%
my_set = {1, 2, 3}

# %%
my_set = {[1, 2, 3]}
# cant be hasshable because list is mutable and unhashable.

# %% [markdown]
# #  Dictionaries

# %%
user = {
    "name": "Vishal",
    "age": 21,
    "skills": ["Python", "ML"]
}

# %%
user["name"]
# Out:
# 'Vishal'

# %%
user["city"]

# %% [markdown]
# Gives markdown

# %%
user.get("city")

# %%
user.get("city", "Unknown")
# Out:
# 'Unknown'

# %%
user = {
    "name": "Vishal",
    "city": None
}

# %%
user.get("city")

# %%
"city" in user
# Out:
# True

# %%
data = {}

# %%
data.setdefault("skills", [])
# Out:
# []

# %%
data["skills"].append("python")

# %%
data
# Out:
# {'skills': ['python']}

# %%
print(data.get("skills"))
# Out:
# ['python']

# %%
user = {
    "name": "Vishal"
}

print(user.get("age"))
# Out:
# 0

# %%
user = {
    "name": "Vishal"
}

print(user.get("age"))
print(user.get("age", 21))
# Out:
# None
# 21

# %%
user = {
    "name": "Vishal",
    "city": None
}

# %%
records = [
    {"name": "A", "age": 20},
    {"name": "B"},
    {"name": "C", "age": None},
]

# %%
for record in records:

    if "age" not in record:
        print(record["name"], "→ missing age")

    elif record["age"] is None:
        print(record["name"], "→ age explicitly set to None")

    else:
        print(record["name"], "→ valid age")
# Out:
# A → valid age
# B → missing age
# C → age explicitly set to None

# %%
user = {
    "name": "Vishal",
    "age": 21,
    "city": "Panipat"
}

# %%
for item in user:
    print(item)
# Out:
# name
# age
# city

# %%
for key, value in user.items():
    print(key, ":", value)
# Out:
# name : Vishal
# age : 21
# city : Panipat

# %%
user = {"name": "Vishal"}

# %%
user.setdefault("age", 21)
print(user)
# Out:
# {'name': 'Vishal', 'age': 21}

# %%
user.setdefault("age", 99)
print(user)
# Out:
# {'name': 'Vishal', 'age': 21}

# %%
from collections import Counter

items = ["python", "ml", "python", "ai", "ml", "python"]
counts = Counter(items)
print(counts)
# Out:
# Counter({'python': 3, 'ml': 2, 'ai': 1})

# %%
from collections import Counter

text = ["a", "b", "a", "c", "b", "a"]
c = Counter(text)

print(c["a"])
print(c["b"])
print(c["z"])
# Out:
# 3
# 2
# 0

# %%
from collections import Counter

text = "banana"
c = Counter(text)

print(c)
# Out:
# Counter({'a': 3, 'n': 2, 'b': 1})

# %%
squares = []
for x in range(6):
    squares.append(x * x)

print(squares)
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
squares = [x * x for x in range(6)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
words = ["a", "bb", "a", "ccc"]
s = {w for w in words}
print(s)
# Out:
# {'a', 'bb', 'ccc'}

# %%
names = ["a", "bb"]
d = {name: len(name) for name in names}
print(d)
# Out:
# {'a': 1, 'bb': 2}

# %%
text = "Machine"

print(text[-2])
print(text[2:6])
# Out:
# n
# chin

# %%
nums = [5, 10, 15, 20, 25]

print(nums[:3])
print(nums[3:])
print(nums[::2])
# Out:
# [5, 10, 15]
# [20, 25]
# [5, 15, 25]

# %%
user = {
    "name": "Vishal",
    "age": 21
}

print("name" in user)
print(21 in user)
# Out:
# True
# False

# %%
a, *b, c = [1, 2, 3, 4, 5]

print(a)
print(b)
print(c)
# Out:
# 1
# [2, 3, 4]
# 5

# %% [markdown]
# 1. 5.2.1 — Conditional logic and loops
# 2. 5.2.2 — Function definition, return values, and side effects
# 3. 5.2.3 — Parameters, arguments, *args , and **kwargs
# 4. 5.2.4 — Default arguments and the mutable-default trap
# 5. 5.2.5 — LEGB scope, global , and nonlocal
# 6. 5.2.6 — Closures and late binding
# 7. 5.2.7 — First-class functions, lambdas, and higher-order functions
# 8. 5.2.8 — Recursion and call-stack limits
# 9. 5.2.9 — Comprehensions and functional helpers
# 10. 5.2.10 — Decorators and functools.wraps

# %%
age = 25
if age < 13:
    category = "child"
elif age < 18:
    category = "teenager"
elif age < 65:
    category = "adult"
else:
    category = "senior"

# %%
fruits = ["apple", "banana", "cherry"]
for idx, fruit in enumerate(fruits):
    print(f"{idx}: {fruit}")

# Looping over a dictionary
person = {"name": "Alice", "age": 30}
for key, value in person.items():
    print(key, value)
# Out:
# 0: apple
# 1: banana
# 2: cherry
# name Alice
# age 30

# %%
count = 0
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Find first even number
nums = [1, 3, 5, 8, 9]
for n in nums:
    if n % 2 == 0:
        print("Found even:", n)
        break
else:
    print("No even numbers")
# Out:
# Found even: 8

# %%
squares = [x**2 for x in range(10)]
even_squares = {x: x**2 for x in range(10) if x % 2 == 0}

# %%
print(squares)
print(even_squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %% [markdown]
# Write a loop that prints numbers from 1 to 20, but:
#
# Skip numbers divisible by 3.
#
# Stop completely if you encounter a number divisible by 10.

# %%
for i in range(1,21):
    if i % 3 == 0:
        continue
    elif i % 10 == 0:
        break
    else:
        print(i)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8

# %%
for i in range(1, 21):   # 1 through 20
    if i % 3 == 0:
        continue
    if i % 10 == 0:
        break
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8

# %% [markdown]
# Write a function validate_username(username) that:
#
# Returns True if the username is non‑empty, at most 20 characters, and contains only letters, digits, or underscores.
#
# Returns False otherwise.
#
# Use guard clauses and avoid unnecessary nesting.

# %%
import re

def validate_username(username: str) -> bool:
    if not isinstance(username, str) or not username:
        return False
    if len(username) > 20:
        return False
    if not re.fullmatch(r"[A-Za-z0-9_]+", username):
        return False
    return True

# %%
def validate_username(username: str) -> bool:
    if not isinstance(username, str) or not username:
        return False
    if len(username) > 20:
        return False
    if not all(c.isalnum() or c== '_' for c in username):
        return False
    return True

# %%
def describe_person(name, age, *hobbies, **details):
    print(f"Name: {name}, Age: {age}")
    if hobbies:
        print("hobbies:"," ,".join(hobbies))
    if details:
        print("Details:")
        for key, value in details.items():
            print(f"  {key}: {value}")

describe_person("Alice", 30, "reading", "hiking", city="Paris", job="Engineer")
# Out:
# Name: Alice, Age: 30
# hobbies: reading ,hiking
# Details:
#   city: Paris
#   job: Engineer

# %%
def append_to(element,target= None):
    if target is None:
        target = []
    target.append(element)
    return target

# %% [markdown]
# Write a function add_item(item, items=[]) that adds item to items and returns the list. Then call it three times without the items argument and show the output. Explain why the output is what it is. After that, rewrite the function correctly to avoid the trap.

# %%
def add_item(item,items=None):
    if items is None:
        items = []
    items.append(item)
    return items

print(add_item(1))
print(add_item(2))
print(add_item(3))
# Out:
# [1]
# [2]
# [3]

# %%
x = 5

def outer():
    x = 10
    def inner():
        global x
        x = 20
    inner()
    print(x)

outer()
print(x)
# Out:
# 10
# 20

# %%
def outer():
    a = 25
    name='python'
    def inner(prefix):
        print(prefix,name)
    return inner

# %%
my_func = outer()

# %%
my_func
# Out:
# <function __main__.outer.<locals>.inner(prefix)>

# %%
my_func("name is")
# Out:
# name is python

# %%
def counter(start):
    def inc(step=1):
        nonlocal start
        start += step
        print(start)
    return inc

# %%
my_inc=counter(5)

# %%
my_inc
# Out:
# <function __main__.counter.<locals>.inc(step=1)>

# %%
my_inc(2)
# Out:
# 7

# %%
my_inc(3)
# Out:
# 10

# %%
another_inc = counter(100)

# %%
another_inc
# Out:
# <function __main__.counter.<locals>.inc(step=1)>

# %%
another_inc(5)
# Out:
# 105
